# %%
import requests

url = "https://api.dataforseo.com/v3/serp/google/organic/live/advanced"

payload="[{\"keyword\":\"site:linkedin.com/in/ 'Alexandre Demain'\", \"location_code\":2826, \"language_code\":\"en\", \"device\":\"desktop\", \"os\":\"macos\", \"depth\":10}]"
headers = {
    'Authorization': 'Basic YWxleGFuZGVyLnd5bmFlbmR0c0BlbnRvdXJhZ2UuaW86ZTE3MjYxNzdiMzc0NTNmMw==',
    'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#     "version": "0.1.20240801",
#     "status_code": 20000,
#     "status_message": "Ok.",
#     "time": "4.1023 sec.",
#     "cost": 0.01,
#     "tasks_count": 1,
#     "tasks_error": 0,
#     "tasks": [
#         {
#             "id": "10101301-8427-0139-0000-a5edd7aecc8f",
#             "status_code": 20000,
#             "status_message": "Ok.",
#             "time": "4.0591 sec.",
#             "cost": 0.01,
#             "result_count": 1,
#             "path": [
#                 "v3",
#                 "serp",
#                 "google",
#                 "organic",
#                 "live",
#                 "advanced"
#             ],
#             "data": {
#                 "api": "serp",
#                 "function": "live",
#                 "se": "google",
#                 "se_type": "organic",
#                 "keyword": "site:linkedin.com\/in\/ 'Alexandre Demain'",
#                 "location_code": 2826,
#                 "language_code": "en",
# ...
